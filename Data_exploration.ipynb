# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filepath='/content/drive/My Drive/Colab Notebooks/HackathonDataset.csv'
df=pd.read_csv(filepath)

# %%
df.head()
# Out:
#    Unnamed: 0  Time        V1        V2        V3        V4        V5  \
# 0           0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321
# 1           1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018
# 2           2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198
# 3           3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309
# 4           4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193
#
#          V6        V7        V8  ...       V22       V23       V24       V25  \
# 0  0.462388  0.239599  0.098698  ...  0.277838 -0.110474  0.066928  0.128539
# 1 -0.082361 -0.078803  0.085102  ... -0.638672  0.101288 -0.339846  0.167170
# 2  1.800499  0.791461  0.247676  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  1.247203  0.237609  0.377436  ...  0.005274 -0.190321 -1.175575  0.647376
# 4  0.095921  0.592941 -0.270533  ...  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class                  Coordinates
# ...

# %%
cities_coordinates = [
    (61.16666667, -150.0166667),
    (33.65, -84.43333333),
    (39.38333333, -74.41666667),
    (30.3, -97.7),
    (39.3, -76.61666667),
    (30.53333333, -91.15),
    (33.51666667, -86.8),
    (42.35, -71.06666667),
    (42.93333333, -78.86666667),
    (46.0, -112.5333333),
    (32.78333333, -79.93333333),
    (35.21666667, -80.95),
    (35.03333333, -85.28333333),
    (41.83333333, -87.61666667),
    (39.1, -84.51666667),
    (41.48333333, -81.61666667),
    (34.0, -81.03333333),
    (32.83333333, -96.76666667),
    (39.75, -105.0),
    (42.5, -90.7),
    (31.75, -106.4833333),
    (36.73333333, -119.8),
    (42.96666667, -85.66666667),
    (47.5, -111.3),
    (44.51666667, -88.0),
    (41.76666667, -72.68333333),
    (46.6, -112.0166667),
    (21.3, -157.8597222),
    (29.75, -95.35),
    (39.76666667, -86.15),
    (30.31666667, -81.65),
    (39.1, -94.58333333),
    (35.96666667, -83.91666667),
    (36.16666667, -115.2),
    (40.8, -96.66666667),
    (34.01666667, -118.2833333),
    (38.25, -85.75),
    (35.11666667, -90.05),
    (25.78333333, -80.21666667),
    (43.03333333, -87.93333333),
    (44.96666667, -93.25),
    (30.68333333, -88.05),
    (36.16666667, -86.78333333),
    (29.96666667, -90.08333333),
    (40.78333333, -73.96666667),
    (36.9, -76.23333333),
    (35.4, -97.6),
    (41.25, -95.93333333),
    (39.95, -75.16666667),
    (33.43333333, -112.0),
    (40.45, -79.98333333),
    (45.51666667, -122.6833333),
    (41.81666667, -71.4),
    (35.81666667, -78.63333333),
]

# %%
import random
df['Coordinates'] = [random.choice(cities_coordinates) for _ in range(len(df))]

# %%
df.head()
# Out:
#    Unnamed: 0  Time        V1        V2        V3        V4        V5  \
# 0           0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321
# 1           1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018
# 2           2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198
# 3           3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309
# 4           4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193
#
#          V6        V7        V8  ...       V22       V23       V24       V25  \
# 0  0.462388  0.239599  0.098698  ...  0.277838 -0.110474  0.066928  0.128539
# 1 -0.082361 -0.078803  0.085102  ... -0.638672  0.101288 -0.339846  0.167170
# 2  1.800499  0.791461  0.247676  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  1.247203  0.237609  0.377436  ...  0.005274 -0.190321 -1.175575  0.647376
# 4  0.095921  0.592941 -0.270533  ...  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class                  Coordinates
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from shapely.geometry import Point
import geopandas as gpd

# %%
df.head()
# Out:
#    Unnamed: 0  Time        V1        V2        V3        V4        V5  \
# 0           0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321
# 1           1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018
# 2           2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198
# 3           3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309
# 4           4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193
#
#          V6        V7        V8  ...       V22       V23       V24       V25  \
# 0  0.462388  0.239599  0.098698  ...  0.277838 -0.110474  0.066928  0.128539
# 1 -0.082361 -0.078803  0.085102  ... -0.638672  0.101288 -0.339846  0.167170
# 2  1.800499  0.791461  0.247676  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  1.247203  0.237609  0.377436  ...  0.005274 -0.190321 -1.175575  0.647376
# 4  0.095921  0.592941 -0.270533  ...  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class                  Coordinates
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8',
#        'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18',
#        'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28',
#        'Amount', 'Class', 'Coordinates'],
#       dtype='object')

# %%
df.shape
# Out:
# (284807, 33)

# %% [markdown]
# 1)Due to security reasons, the original features V1, V2, V3 ....,V27, V28 have been modified by PCA.We can guess that these features could be credit card number,cv number,card holder name etc.
#
# 2)The only feature that are not modified by PCA are Amount, Time,Latitude, Longitude.So we should focus on processing these features

# %% [markdown]
# **Checking for missing values**

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Time           0
# V1             0
# V2             0
# V3             0
# V4             0
# V5             0
# V6             0
# V7             0
# V8             0
# V9             0
# V10            0
# V11            0
# V12            0
# V13            0
# V14            0
# V15            0
# V16            0
# V17            0
# V18            0
# V19            0
# V20            0
# V21            0
# V22            0
# V23            0
# V24            0
# V25            0
# V26            0
# V27            0
# V28            0
# Amount         0
# Class          0
# Coordinates    0
# dtype: int64

# %% [markdown]
# There are no missing values in the given dataset.

# %%
df.describe()
# Out:
#           Unnamed: 0           Time            V1            V2            V3  \
# count  284807.000000  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05
# mean   142403.000000   94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15
# std     82216.843396   47488.145955  1.958696e+00  1.651309e+00  1.516255e+00
# min         0.000000       0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01
# 25%     71201.500000   54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01
# 50%    142403.000000   84692.000000  1.810880e-02  6.548556e-02  1.798463e-01
# 75%    213604.500000  139320.500000  1.315642e+00  8.037239e-01  1.027196e+00
# max    284806.000000  172792.000000  2.454930e+00  2.205773e+01  9.382558e+00
#
#                  V4            V5            V6            V7            V8  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   2.074095e-15  9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16
# ...

# %%
df['Amount'].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# 1)The mean transcation amount is 88.34 with standard deviation of 250.12.
#
# 2)The minimum transaction amount is 0 while the maximum transaction amount is 25691.16.

# %%
df['Time'].describe()
# Out:
# count    284807.000000
# mean      94813.859575
# std       47488.145955
# min           0.000000
# 25%       54201.500000
# 50%       84692.000000
# 75%      139320.500000
# max      172792.000000
# Name: Time, dtype: float64

# %% [markdown]
# 1)On an average the transaction takes place every 94813 seconds.

# %% [markdown]
# As we have to use geo-spatial analysis ,we need to store the coordinats located in the 'Coordinates' column ina more standardized format, such as Well-Known-Text(WKT) or GeoJSON.For this we use the shapely library to convert coordinates into WKT.

# %%
# !pip install geopy geojson

# %%
df.head()
# Out:
#    Unnamed: 0  Time        V1        V2        V3        V4        V5  \
# 0           0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321
# 1           1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018
# 2           2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198
# 3           3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309
# 4           4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193
#
#          V6        V7        V8  ...       V23       V24       V25       V26  \
# 0  0.462388  0.239599  0.098698  ... -0.110474  0.066928  0.128539 -0.189115
# 1 -0.082361 -0.078803  0.085102  ...  0.101288 -0.339846  0.167170  0.125895
# 2  1.800499  0.791461  0.247676  ...  0.909412 -0.689281 -0.327642 -0.139097
# 3  1.247203  0.237609  0.377436  ... -0.190321 -1.175575  0.647376 -0.221929
# 4  0.095921  0.592941 -0.270533  ... -0.137458  0.141267 -0.206010  0.502292
#
#         V27       V28  Amount  Class                  Coordinates  \
# ...

# %% [markdown]
# We have converted the coordinates into WKT format and so now dropping the Coordinates column.

# %%
df.drop('Unnamed: 0',axis=1, inplace=True)

# %%
df.drop('Coordinates',axis=1, inplace=True)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 32 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# This dataset has 30 float independent variables,1 object type variable and 1 integer target variable  'Class' and there are no missing values.

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df['Class'].value_counts()/len(df['Class'])
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: count, dtype: float64

# %%
f,ax=plt.subplots(figsize=(6,8))
ax=sns.countplot(x='Class',data=df,palette='Set1')
plt.show()
# Out:
# <ipython-input-25-bff70eeb10b9>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x='Class',data=df,palette='Set1')

# %% [markdown]
# This dataset contains transaction information with 492 fraud transactions out of the total 284,807 transactions.This is a severely imbalanced dataset with positive class(fraud) accounting for only 0.172% of all the transactions.

# %% [markdown]
# Creating two seperate datasets named fraud, normal which contains records of fraud and normal transactions from the given dataset

# %%
fraud=df[df['Class']==1]
normal=df[df['Class']==0]
print('The shape of the Normal Transactions: {}\n'.format(normal.shape))
print('The shape of the Fraud Transactions : {}\n'.format(fraud.shape))
# Out:
# The shape of the Normal Transactions: (284315, 32)
#
# The shape of the Fraud Transactions : (492, 32)

# %% [markdown]
# **Distribution of Time**

# %%
plt.figure(figsize=(8,6))
sns.distplot(df['Time'],bins=100)
plt.title('Distribution of transaction Time',fontsize=16)
plt.show()
# Out:
# <ipython-input-27-bd7de3df10f9>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Time'],bins=100)

# %% [markdown]
# This dataset contains two day trading information , looking at the distribution chart we see two peaks and two troughs. Most likely the two peaks are the transactions dutring daytime because of the high volume of transations, and the two troughs are transactions at night when everyone is asleep.

# %%
fig,axs=plt.subplots(ncols=2,figsize=(16,4))

sns.histplot(fraud['Time'],bins=100,color='red',ax=axs[0])
axs[0].set_title("Distribution of Fraud Transactions.",fontsize=8)

sns.histplot(normal['Time'],bins=100,color='green',ax=axs[1])
axs[1].set_title("Distribution of Normal Trnasaction",fontsize=8)
# Out:
# Text(0.5, 1.0, 'Distribution of Normal Trnasaction')

# %% [markdown]
# **Distribution of Amount**

# %%
fig,axs=plt.subplots(ncols=2,figsize=(16,4))

sns.histplot(fraud['Amount'],bins=100,ax=axs[0])
axs[0].set_title("Distribution of Fraud Amount",fontsize=8)

sns.histplot(normal['Amount'],bins=100,ax=axs[1])
axs[1].set_title("distribution of Normal Amount",fontsize=8)
# Out:
# Text(0.5, 1.0, 'distribution of Normal Amount')

# %% [markdown]
# We observe that the column 'Amount' does not follow the gaussian normal distribution but it follows skewed distribution.

# %%
#scaling the Amount column by log
df['Amount_log']=np.log(df['Amount']+0.0001)

# %% [markdown]
# Log transformations are highly useful for converting the skewed distribution into gaussian normal distribution because they they tend expand values in lower magnitude range and tend to compress /reduce the values in the highermagnitude range.

# %%
fraud=df[df['Class']==1]
normal=df[df['Class']==0]

# %%
fig,axs=plt.subplots(ncols=2,figsize=(16,4))

sns.histplot(fraud['Amount_log'],bins=100,ax=axs[0])
axs[0].set_title("Distribution of Fraud Amount",fontsize=8)

sns.histplot(normal['Amount_log'],bins=100,ax=axs[1])
axs[1].set_title("distribution of Normal Amount",fontsize=8)
# Out:
# Text(0.5, 1.0, 'distribution of Normal Amount')

# %% [markdown]
# **Relationship of fraud transactions with amount of money**
#
# Let us try to determine the nature of transactions which are fraud and obtain a relevant set of the same with respect to their amount.
#
# We hypothesise based on our scatter plot that all fraud transactions occur for an amount less than 2500.

# %%
# Create a scatterplot
sns.scatterplot(x="Time", y="Amount", hue="Class", data=df, palette={0: "#ADD8E6", 1: "#6c5ce7"})
plt.show()

# %% [markdown]
# **Insights**
#
# 1)It can be observed that fraud transcations are generally not above an amount of 2500
#
# 2)It can also be observed that the fraud transactions are evenly distributed about time.

# %%
df_refine = df[["Time", "Amount", "Class"]]

# %%
amount_more = 0
amount_less = 0
for i in range(df_refine.shape[0]):
    if(df_refine.iloc[i]["Amount"] < 2500):
        amount_less += 1
    else:
        amount_more += 1
print(amount_more)
print(amount_less)
# Out:
# 449
# 284358

# %%
percentage_less = (amount_less/df.shape[0])*100
percentage_less
# Out:
# 99.84234938045763

# %% [markdown]
# So now out of the total transactions, 449 transactions have amount greater than 2500 while reamnining 284358 transactions have amount less than 2500.
#
# That is 99.84% of the total transactions have amount less than 2500

# %%
fraud =0
legitimate =0
for i in range(df_refine.shape[0]):
    if(df_refine.iloc[i]["Amount"]<2500):
        if(df_refine.iloc[i]["Class"] == 0):
            legitimate += 1
        else:
            fraud+=1
print(fraud)
print(legitimate)
# Out:
# 492
# 283866

# %%
fraudtot=0
for i in range(df_refine.shape[0]):
  if(df_refine.iloc[i]["Class"]==1):
    fraudtot+=1

print(fraudtot)
# Out:
# 492

# %% [markdown]
# So now we notice that total number of fraud transactions=492
#
# Also the total number of fraud transactions with Amount<2500 =492
#
# Thus we can say that **all the fraud transactions have amount <2500**.

# %% [markdown]
# **Plotting a Correlation Matrix**

# %%
plt.figure(figsize=(20,20))
df_corr = df.iloc[:,:-3].corr()
sns.heatmap(df_corr)
# Out:
# <Axes: >

# %% [markdown]
# **Plotting the correlation matrix seperately for Fraud and Normal Class**

# %%
f, (ax1, ax2) = plt.subplots(1,2,figsize =( 18, 8))
corr = df.iloc[:,:-2].corr()
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap((df.iloc[:,:-2].loc[df['Class'] ==1]).corr(), vmax = .8, square=True, ax = ax1, cmap = 'afmhot', mask=mask,);
ax1.set_title('Fraud')
sns.heatmap((df.iloc[:,:-2].loc[df['Class'] ==0]).corr(), vmax = .8, square=True, ax = ax2, cmap = 'YlGnBu', mask=mask);
ax2.set_title('Normal')
plt.show()
